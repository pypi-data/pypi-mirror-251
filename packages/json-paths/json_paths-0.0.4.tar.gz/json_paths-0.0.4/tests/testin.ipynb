# %%
# %load_ext autoreload
# %autoreload 2
import json 
import sys 
import dataclasses
import pandas as pd 
from attr import dataclass 


sys.path.append('..')
from src.jsonpaths import JsonPaths

with open('/workspaces/jsonpaths/tests/data/workspacescan_results_20231023_144526043.json', 'r') as jfile:
    jfile = json.load(jfile)
jpath = JsonPaths(jfile)
sc = jpath.generate_schema()
df = pd.DataFrame(sc)
#df = jpath.retrieve_objects('root.workspaces.datasets',return_type='dataframe',collapse_parent_fields=['root.workspaces.*'],flatten_inner_objects=True)

df
# Out:
#                                              full_path    item_name  \
# 0                                                 root         root
# 1                                      root.workspaces   workspaces
# 2                                   root.workspaces.id           id
# 3                                 root.workspaces.name         name
# 4                          root.workspaces.description  description
# ..                                                 ...          ...
# 182  root.misconfiguredDatasourceInstances.connecti...       server
# 183  root.misconfiguredDatasourceInstances.connecti...     database
# 184  root.misconfiguredDatasourceInstances.connecti...         path
# 185  root.misconfiguredDatasourceInstances.connecti...         kind
# 186  root.misconfiguredDatasourceInstances.connecti...          url
#
#                                            parent_path        parent_name  \
# 0                                                 root               root
# 1                                                 root               root
# 2                                      root.workspaces         workspaces
# 3                                      root.workspaces         workspaces
# 4                                      root.workspaces         workspaces
# ..                                                 ...                ...
# 182  root.misconfiguredDatasourceInstances.connecti...  connectionDetails
# 183  root.misconfiguredDatasourceInstances.connecti...  connectionDetails
# 184  root.misconfiguredDatasourceInstances.connecti...  connectionDetails
# 185  root.misconfiguredDatasourceInstances.connecti...  connectionDetails
# 186  root.misconfiguredDatasourceInstances.connecti...  connectionDetails
#
#      total_values  samples_taken item_type  is_nullable       other_info
# 0               1              0    object        False  OBJECT_IN_ARRAY
# 1             100              0    object        False  OBJECT_IN_ARRAY
# 2             100            100    STRING        False  FIELD_IN_OBJECT
# 3             100            100    STRING        False  FIELD_IN_OBJECT
# 4              20             20    STRING        False  FIELD_IN_OBJECT
# ..            ...            ...       ...          ...              ...
# 182            30             30    STRING        False  FIELD_IN_OBJECT
# 183            30             30    STRING        False  FIELD_IN_OBJECT
# 184            62             62    STRING        False  FIELD_IN_OBJECT
# 185            10             10    STRING        False  FIELD_IN_OBJECT
# 186             5              5    STRING        False  FIELD_IN_OBJECT
#
# [187 rows x 9 columns]

# %%
star_strings = ['root.workspaces']

all_flds = [y.get('full_path') for x in star_strings for y in jpath.json_schema if y.get('parent_path') == x and y.get('other_info') == 'FIELD_IN_OBJECT' ]

# %%
# %load_ext autoreload
# %autoreload 2
import json 
import sys 
import pandas as pd 
sys.path.append('..')
from src.jsonpaths import JsonPaths

with open('/workspaces/jsonpaths/tests/data/example.json', 'r') as jfile:
    jfile = json.load(jfile)
jpath = JsonPaths(jfile,rootname='approot')
sc = jpath.generate_schema()
df = pd.DataFrame(sc)
df = jpath.retrieve_objects('root.workspaces.datasets',return_type='dataframe',collapse_parent_fields=['root.workspaces.*'],flatten_inner_objects=True)

df
# Out:
#                                       full_path        item_name  \
# 0                                       approot          approot
# 1                               approot.web-app          web-app
# 2                       approot.web-app.servlet          servlet
# 3          approot.web-app.servlet.servlet-name     servlet-name
# 4         approot.web-app.servlet.servlet-class    servlet-class
# ..                                          ...              ...
# 66  approot.web-app.servlet-mapping.fileServlet      fileServlet
# 67   approot.web-app.servlet-mapping.cofaxTools       cofaxTools
# 68                       approot.web-app.taglib           taglib
# 69            approot.web-app.taglib.taglib-uri       taglib-uri
# 70       approot.web-app.taglib.taglib-location  taglib-location
#
#                         parent_path      parent_name  total_values  \
# 0                           approot          approot             1
# 1                           approot          approot             1
# 2                   approot.web-app          web-app             5
# 3           approot.web-app.servlet          servlet             5
# 4           approot.web-app.servlet          servlet             5
# ..                              ...              ...           ...
# 66  approot.web-app.servlet-mapping  servlet-mapping             1
# 67  approot.web-app.servlet-mapping  servlet-mapping             1
# 68                  approot.web-app          web-app             1
# 69           approot.web-app.taglib           taglib             1
# 70           approot.web-app.taglib           taglib             1
#
#     samples_taken item_type  is_nullable        other_info
# 0               0    object        False   OBJECT_IN_ARRAY
# 1               0  object_z        False  OBJECT_IN_OBJECT
# 2               0    object        False   OBJECT_IN_ARRAY
# 3               5    STRING        False   FIELD_IN_OBJECT
# 4               5    STRING        False   FIELD_IN_OBJECT
# ..            ...       ...          ...               ...
# 66              1    STRING        False   FIELD_IN_OBJECT
# 67              1    STRING        False   FIELD_IN_OBJECT
# 68              0  object_z        False  OBJECT_IN_OBJECT
# 69              1    STRING        False   FIELD_IN_OBJECT
# 70              1    STRING        False   FIELD_IN_OBJECT
#
# [71 rows x 9 columns]

# %%
int_exm = 1 
dec_exm = 1.01 
str_exm = 'astring' 
bool_exm = True  
type_l = [int_exm, dec_exm,str_exm,bool_exm,None]
for t in type_l:
    print(str(type(t).__name__))
# Out:
# int
# float
# str
# bool
# NoneType
